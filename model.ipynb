# %%
import tensorflow as tf
import numpy as np
from prepare_dataset import PrepareDataset
from train import train_model, translate, evaluate_bleu

# %%
dataset_prep = PrepareDataset(n_sentences=50000)
train_ds, val_ds, en_seq_len, de_seq_len, en_vocab, de_vocab = dataset_prep('dataset/train', batch_size=32)
# Out:
# Processing data...
# ...
# Loading subset: 100%|██████████| 50000/50000 [00:00<00:00, 1099505.08it/s]
# Vocab sizes: EN=22308, DE=48031
# Seq lengths: EN=184, DE=171

# %%
# Train the Model
trained_model, en_tok, de_tok, en_len, de_len = train_model(epochs=10, batch_size=32, n_sentences=50000)
# Out:
# Processing data...
# Loading subset: 100%|██████████| 50000/50000 [00:00<00:00, 1115103.05it/s]
# Vocab sizes: EN=22308, DE=48031
# Seq lengths: EN=184, DE=171
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Train the Model
# ----> 2 trained_model, en_tok, de_tok, en_len, de_len = train_model(epochs=10, batch_size=32, n_sentences=50000)
#
# File c:\Users\Pratyush\Desktop\Projects\Complete Project\train.py:64, in train_model(epochs, batch_size, n_sentences, d_model, h, d_k, d_v, d_ff, n, dropout_rate)
#      61 train_ds, val_ds, en_seq_len, de_seq_len, en_vocab, de_vocab = dataset_prep('dataset/train', batch_size=batch_size)
#      63 # Create model
# ---> 64 model = TransformerModel(en_vocab, de_vocab, en_seq_len, de_seq_len, h, d_k, d_v, d_model, d_ff, n, dropout_rate)
#      66 # Optimizer
# ...
