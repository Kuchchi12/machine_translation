# %%
import pandas as pd
import os

# %%
# %cd nmt
# Out:
# C:\Users\Pratyush\Desktop\Capstone_Project\nmt

# %%
with open(file='dataset/train/europarl-v7_de_en.txt', mode='rb') as file:
    lines_train_de = file.read()

with open(file='dataset/train/europarl-v7_en_de.txt', mode='rb') as file:
    lines_train_en = file.read()

# %%
with open(file='dataset/train/europarl-v7_de_en.txt', mode='rb') as file:
    lines_train_de_test = file.readlines()

# %%
len(lines_train_de_test)
# Out:
# 1920209

# %%
print(len(lines_train_de))
print(len(lines_train_en))
# Out:
# 328463491
# 287250069

# %%
lines_train_en[2]
# Out:
# 115

# %%
data_de = lines_train_de.decode().split('\n')
data_en = lines_train_en.decode().split('\n')

# %%
print(len(data_de))
print(len(data_en))
# Out:
# 1920210
# 1920210

# %%
data_comb = [[i,j] for i, j in zip(data_de, data_en)]
data_comb[0]
# Out:
# ['Wiederaufnahme der Sitzungsperiode', 'Resumption of the session']

# %%
import numpy as np

# %%
X = np.array(data_comb)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 X = np.array(data_comb)
#
# MemoryError: Unable to allocate 56.5 GiB for an array with shape (1920210, 2) and data type <U3950

# %%
with open('dataset/train/train_de_en.pkl', 'wb') as file:
    dump(X, file)

# %%
len(data_ger)
# Out:
# 1

# %%
print(data_ger)
# Out:
# ['']

# %%
import glob

# %%
train_text_files = glob.glob(os.path.join('dataset/train', '*.txt'))

# %%
train_text_files[0].split('_')[-2]
# Out:
# 'de'

# %%
train_text_files[0]
# Out:
# 'dataset/train\\europarl-v7_de_en.txt'

# %%
with open(train_text_files[0],'rb') as file:
